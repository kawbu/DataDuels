# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
set1 = pd.read_csv("LeetCodeDataset_train.csv")
set2 = pd.read_csv("LeetCodeQuestions_detailed.csv")

print("Columns in set1:")
print(set1.columns.tolist())
print("\nColumns in set2:")
print(set2.columns.tolist())
# Out:
# Columns in set1:
# ['task_id', 'question_id', 'difficulty', 'tags', 'problem_description', 'starter_code', 'estimated_date', 'prompt', 'completion', 'entry_point', 'test', 'input_output', 'query', 'response']
#
# Columns in set2:
# ['questionFrontendId', 'questionTitle', 'TitleSlug', 'content', 'difficulty', 'totalAccepted', 'totalSubmission', 'totalAcceptedRaw', 'totalSubmissionRaw', 'acRate', 'similarQuestions', 'mysqlSchemas', 'category', 'codeDefinition', 'sampleTestCase', 'metaData', 'envInfo', 'topicTags']
